# %%
import pandas as pd
from sqlalchemy import create_engine
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
MVR_df = pd.read_excel('https://opendata.stadt-muenster.de/sites/default/files/Fahrzeugbestand-Regierungsbezirk-Muenster-2018-2022.xlsx',skiprows=1)
print(MVR_df)
# Out:
#       Jahr                   Regierungsbezirk  \
# 0   2022.0  RB MUENSTER
# 1      NaN                                NaN
# 2      NaN                                NaN
# 3      NaN                                NaN
# 4      NaN                                NaN
# 5      NaN                                NaN
# 6      NaN                                NaN
# 7      NaN                                NaN
# 8      NaN                                NaN
# 9   2021.0  RB MUENSTER
# 10     NaN                                NaN
# 11     NaN                                NaN
# 12     NaN                                NaN
# 13     NaN                                NaN
# 14     NaN                                NaN
# 15     NaN                                NaN
# 16     NaN                                NaN
# 17     NaN                                NaN
# 18  2020.0  RB MUENSTER
# 19     NaN                                NaN
# 20     NaN                                NaN
# 21     NaN                                NaN
# 22     NaN                                NaN
# 23     NaN                                NaN
# 24     NaN                                NaN
# 25     NaN                                NaN
# 26     NaN                                NaN
# 27  2019.0  RB MUENSTER
# 28     NaN                                NaN
# 29     NaN                                NaN
# 30     NaN                                NaN
# 31     NaN                                NaN
# 32     NaN                                NaN
# 33     NaN                                NaN
# 34     NaN                                NaN
# 35     NaN                                NaN
# 36  2018.0                        RB MUENSTER
# 37     NaN                                NaN
# 38     NaN                                NaN
# 39     NaN                                NaN
# 40     NaN                                NaN
# 41     NaN                                NaN
# 42     NaN                                NaN
# 43     NaN                                NaN
# 44     NaN                                NaN
#
#    Statistische Kennziffer und Zulassungsbezirk  insgesamt  \
# 0                          05512  BOTTROP,STADT       6540
# 1                    05513  GELSENKIRCHEN,STADT       9564
# 2                         05515  MUENSTER,STADT      11038
# 3                                 05554  BORKEN      17873
# 4                               05558  COESFELD      13223
# 5                         05562  RECKLINGHAUSEN      34032
# 6                              05566  STEINFURT      23773
# 7                              05570  WARENDORF      15056
# 8                                        GESAMT     131099
# 9      05512  BOTTROP,STADT                           6385
# 10     05513  GELSENKIRCHEN,STADT                     9419
# 11     05515  MUENSTER,STADT                         10800
# 12     05554  BORKEN                                 17306
# 13     05558  COESFELD                               12969
# 14     05562  RECKLINGHAUSEN                         33492
# 15     05566  STEINFURT                              23245
# 16     05570  WARENDORF                              14816
# 17                                       GESAMT     128432
# 18     05512  BOTTROP,STADT                           6167
# 19     05513  GELSENKIRCHEN,STADT                     9189
# 20     05515  MUENSTER,STADT                         10531
# 21     05554  BORKEN                                 16681
# 22     05558  COESFELD                               12654
# 23     05562  RECKLINGHAUSEN                         32542
# 24     05566  STEINFURT                              22472
# 25     05570  WARENDORF                              14380
# 26                                       GESAMT     124616
# 27     05512  BOTTROP,STADT                           6145
# 28     05513  GELSENKIRCHEN,STADT                     9158
# 29     05515  MUENSTER,STADT                         10498
# 30     05554  BORKEN                                 16476
# 31     05558  COESFELD                               12422
# 32     05562  RECKLINGHAUSEN                         32199
# 33     05566  STEINFURT                              22224
# 34     05570  WARENDORF                              14258
# 35                                       GESAMT     123380
# 36     05512  BOTTROP,STADT                           6094
# 37     05513  GELSENKIRCHEN,STADT                     9137
# 38     05515  MUENSTER,STADT                         10442
# 39     05554  BORKEN                                 16321
# 40     05558  COESFELD                               12207
# 41     05562  RECKLINGHAUSEN                         31909
# 42     05566  STEINFURT                              22107
# 43     05570  WARENDORF                              14173
# 44                                       GESAMT     122390
#
#     davon \nzweirädrige \nKfz  davon \ndreirädrige \nKfz  \
# 0                        6398                         65
# 1                        9265                        154
# 2                       10802                        136
# 3                       17282                        207
# 4                       12815                        140
# 5                       33314                        332
# 6                       23019                        200
# 7                       14667                        134
# 8                      127562                       1368
# 9                        6251                         62
# 10                       9137                        133
# 11                      10558                        120
# 12                      16734                        192
# 13                      12578                        113
# 14                      32757                        335
# 15                      22497                        196
# 16                      14433                        118
# 17                     124945                       1269
# 18                       6049                         54
# 19                       8923                        114
# 20                      10287                        117
# 21                      16115                        181
# 22                      12256                        109
# 23                      31825                        293
# 24                      21750                        176
# 25                      14009                        106
# 26                     121214                       1150
# 27                       6031                         43
# 28                       8883                        107
# 29                      10268                        106
# 30                      15915                        167
# 31                      12026                        110
# 32                      31501                        268
# 33                      21521                        154
# 34                      13882                        105
# 35                     120027                       1060
# 36                       5967                         44
# 37                       8878                         99
# 38                      10223                         97
# 39                      15756                        155
# 40                      11825                         97
# 41                      31236                        230
# 42                      21407                        146
# 43                      13792                         91
# 44                     119084                        959
#
#     davon \nleichte \nvierrädrige Kfz  darunter \nweibliche \nHalter  \
# 0                                  77                            850
# 1                                 145                           1258
# 2                                 100                           1584
# 3                                 384                           2475
# 4                                 268                           1863
# 5                                 386                           4909
# 6                                 554                           3219
# 7                                 255                           2010
# 8                                2169                          18168
# 9                                  72                            851
# 10                                149                           1232
# 11                                122                           1538
# 12                                380                           2384
# 13                                278                           1826
# 14                                400                           4802
# 15                                552                           3115
# 16                                265                           2001
# 17                               2218                          17749
# 18                                 64                            806
# 19                                152                           1210
# 20                                127                           1515
# 21                                385                           2294
# 22                                289                           1769
# 23                                424                           4675
# 24                                546                           3004
# 25                                265                           1927
# 26                               2252                          17200
# 27                                 71                            819
# 28                                168                           1201
# 29                                124                           1507
# 30                                394                           2249
# 31                                286                           1716
# 32                                430                           4590
# 33                                549                           3006
# 34                                271                           1946
# 35                               2293                          17034
# 36                                 83                            811
# 37                                160                           1191
# 38                                122                           1520
# 39                                410                           2271
# 40                                285                           1717
# 41                                443                           4591
# 42                                554                           3048
# 43                                290                           1924
# 44                               2347                          17073
#
#     insgesamt.1  Hubraum\nbis \n1.399 cm³  ...  unbe-\nkannt.1  insgesamt.3  \
# 0         69922                     29380  ...               -          835
# 1        124908                     51842  ...               2         1130
# 2        151531                     54551  ...               4         2504
# 3        231725                     80907  ...               4        14152
# 4        143139                     52056  ...               3         8884
# 5        361126                    148951  ...               6         5908
# 6        281036                    102142  ...               2        15736
# 7        176360                     64504  ...               5        10218
# 8       1539747                    584333  ...              26        59367
# 9         69565                     29432  ...               -          790
# 10       124514                     51756  ...               1         1096
# 11       150277                     54124  ...               3         2492
# 12       229037                     80490  ...               4        13728
# 13       142027                     51759  ...               2         8646
# 14       359727                    148916  ...               7         5756
# 15       278271                    101827  ...               2        15305
# 16       174862                     64232  ...               5        10064
# 17      1528280                    582536  ...              24        57877
# 18        68867                     29458  ...               -          775
# 19       123028                     51380  ...               1         1051
# 20       147332                     52912  ...               2         2492
# 21       225320                     79410  ...               4        13470
# 22       140311                     51461  ...               2         8360
# 23       354897                    147786  ...               9         5701
# 24       273755                    100861  ...               1        15169
# 25       172580                     63290  ...               4         9927
# 26      1506090                    576558  ...              23        56945
# 27        67632                     28725  ...               -          786
# 28       121583                     50309  ...               1          999
# 29       145681                     51526  ...               1         2496
# 30       221053                     77461  ...               6        13217
# 31       137930                     50333  ...               2         8228
# 32       350049                    144300  ...              10         5674
# 33       268892                     98559  ...               2        14931
# 34       169470                     61217  ...               3         9788
# 35      1482290                    562430  ...              25        56119
# 36        66709                     27860  ...               2          741
# 37       120310                     49077  ...               -         1000
# 38       143295                     49373  ...               1         2439
# 39       216709                     74820  ...               5        12838
# 40       135244                     48336  ...               1         8063
# 41       345573                    139979  ...               7         5530
# 42       263751                     95099  ...               1        14660
# 43       166325                     58847  ...               4         9676
# 44      1457916                    543391  ...              21        54947
#
#     davon\nSattelzug-\nmaschinen  \
# 0                            284
# 1                            652
# 2                            558
# 3                           2568
# 4                            896
# 5                           1660
# 6                           2534
# 7                           1476
# 8                          10628
# 9                            261
# 10                           667
# 11                           589
# 12                          2446
# 13                           886
# 14                          1661
# 15                          2453
# 16                          1411
# 17                         10374
# 18                           251
# 19                           616
# 20                           634
# 21                          2428
# 22                           769
# 23                          1696
# 24                          2564
# 25                          1384
# 26                         10342
# 27                           274
# 28                           561
# 29                           641
# 30                          2320
# 31                           758
# 32                          1748
# 33                          2557
# 34                          1330
# 35                         10189
# 36                           250
# 37                           582
# 38                           594
# 39                          2188
# 40                           727
# 41                          1673
# 42                          2544
# 43                          1311
# 44                          9869
#
#     davon\nland-/forst-\nwirtschaft-\nliche Zug-\nmaschinen  \
# 0                                                 459
# 1                                                 418
# 2                                                1662
# 3                                               10095
# 4                                                6677
# 5                                                3633
# 6                                               11166
# 7                                                7507
# 8                                               41617
# 9                                                 407
# 10                                                330
# 11                                               1500
# 12                                               9461
# 13                                               6219
# 14                                               3303
# 15                                              10401
# 16                                               7216
# 17                                              38837
# 18                                                403
# 19                                                333
# 20                                               1454
# 21                                               9215
# 22                                               6046
# 23                                               3201
# 24                                              10157
# 25                                               7093
# 26                                              37902
# 27                                                391
# 28                                                338
# 29                                               1441
# 30                                               9099
# 31                                               5924
# 32                                               3127
# 33                                               9942
# 34                                               6991
# 35                                              37253
# 36                                                375
# 37                                                319
# 38                                               1428
# 39                                               8870
# 40                                               5810
# 41                                               3058
# 42                                               9721
# 43                                               6893
# 44                                              36474
#
#     davon\nsonstige Zug-\nmaschinen  Unnamed: 34  Unnamed: 35  insgesamt.4  \
# 0                                92          269         4843        81305
# 1                                60          497        10068       144540
# 2                               284          742        13912       176481
# 3                              1489         1839        35190       284788
# 4                              1311         1075        19605       175967
# 5                               615         1478        25996       421154
# 6                              2036         1692        36848       341657
# 7                              1235         1040        21654       213070
# 8                              7122         8632       168116      1838962
# 9                                41          257         4600        80550
# 10                               61          478         9569       143502
# 11                              109          744        13232       174309
# 12                              356         1787        33848       280191
# 13                              281         1017        18894       173890
# 14                              352         1448        24956       418175
# 15                              384         1638        35406       336922
# 16                              295         1001        21158       210836
# 17                             1879         8370       161663      1818375
# 18                               32          243         4426        79460
# 19                               55          458         9087       141304
# 20                               83          723        12561       170424
# 21                              319         1707        32816       274817
# 22                              234          977        18144       171109
# 23                              309         1416        24062       411501
# 24                              337         1604        34487       330714
# 25                              260          955        20586       207546
# 26                             1629         8083       156169      1786875
# 27                               33          230         4250        78027
# 28                               56          462         8787       139528
# 29                               72          713        12271       168450
# 30                              290         1630        31814       269343
# 31                              217          943        17598       167950
# 32                              273         1379        23329       405577
# 33                              290         1603        33512       324628
# 34                              247          931        20063       203791
# 35                             1478         7891       151624      1757294
# 36                               27          225         4127        76930
# 37                               46          461         8490       137937
# 38                               53          709        11906       165643
# 39                              256         1576        30741       263771
# 40                              191          901        16985       164436
# 41                              249         1389        22584       400066
# 42                              259         1533        32499       318357
# 43                              227          913        19532       200030
# 44                             1308         7707       146864      1727170
#
#     Kfz-Dichte\nje 1.000 \nEinwohner  Unnamed: 38
# 0                                693         6121
# 1                                558         9538
# 2                                558        17575
# 3                                766        50775
# 4                                797        29596
# 5                                686        41487
# 6                                762        60733
# 7                                768        33726
# 8                                701       249551
# 9                                685         5939
# 10                               553         9240
# 11                               553        17303
# 12                               755        48859
# 13                               788        28860
# 14                               681        40406
# 15                               752        58681
# 16                               759        32677
# 17                               693       241965
# 18                               677         5742
# 19                               542         9019
# 20                               542        16950
# 21                               741        47625
# 22                               778        28062
# 23                               669        39485
# 24                               739        57188
# 25                               747        31906
# 26                               681       235977
# 27                               665         5628
# 28                               536         8705
# 29                               537        16548
# 30                               729        46373
# 31                               766        27356
# 32                               658        38443
# 33                               727        55566
# 34                               734        31087
# 35                               670       229706
# 36                               657         5400
# 37                               530         8549
# 38                               534        16226
# 39                               714        44951
# 40                               753        26577
# 41                               648        37498
# 42                               718        54167
# 43                               721        30275
# 44                               661       223643
#
# [45 rows x 39 columns]

# %%
BS_df = pd.read_csv(r"C:\Users\Alimu\Downloads\rad_tage.csv")
#data can be download from the link ("https://www.kaggle.com/code/docxian/bike-traffic-in-munich")
print(BS_df.head())
# Out:
#         datum uhrzeit_start uhrzeit_ende zaehlstelle  richtung_1  richtung_2  \
# 0  2017.01.01         00:00        23:59      Arnulf         121          14
# 1  2017.01.01         00:00        23:59     Erhardt         253         278
# 2  2017.01.01         00:00        23:59      Hirsch          67          74
# 3  2017.01.01         00:00        23:59    Kreuther          14          16
# 4  2017.01.01         00:00        23:59  Margareten         197         187
#
#    gesamt  min-temp  max-temp  niederschlag  bewoelkung  sonnenstunden
# 0     135      -6.1       2.6           0.0          36            5.9
# 1     531      -6.1       2.6           0.0          36            5.9
# 2     141      -6.1       2.6           0.0          36            5.9
# 3      30      -6.1       2.6           0.0          36            5.9
# 4     384      -6.1       2.6           0.0          36            5.9

# %%
#Cleaning of Munich Vehicle Registration data to acquire only required columns

# Specify the number of columns to include
num_columns = 20

# Slice the DataFrame to store up to the specified number of columns
new_mvr_df = MVR_df.iloc[:, :num_columns]

# Display the new DataFrame with only specified number of column names 
print(new_mvr_df.columns)
# Out:
# Index(['Jahr', 'Regierungsbezirk',
#        'Statistische Kennziffer und Zulassungsbezirk', 'insgesamt',
#        'davon \nzweirädrige \nKfz', 'davon \ndreirädrige \nKfz',
#        'davon \nleichte \nvierrädrige Kfz', 'darunter \nweibliche \nHalter',
#        'insgesamt.1', 'Hubraum\nbis \n1.399 cm³', '1.400\nbis\n1.999 cm³',
#        '2.000\nund\nmehr cm³', 'unbe-\nkannt',
#        'und zwar \nmit\noffenem\nAufbau', 'und zwar \nmit\nAllrad-\nantrieb',
#        'und zwar Wohn-\nmobile',
#        'und zwar \nKranken-\nwagen,\nNotarzt-\neinsatzfz.',
#        'und zwar \ngewerbliche\nHalter', 'und zwar \nweibliche\nHalter',
#        'PKW-Dichte\nje 1.000 \nEinwohner'],
#       dtype='object')

# %%
#Changing of column names to English for ease 

# Define the new column names
new_column_names = ['Year', 'Administrative district', 'Statistical code and registration district', 'altogether', 'therefrom Two-wheeled Car', 'of that three-wheeled car', 'of that light four-wheeled vehicles', 'underneath female Holder', 'passenger cars total', 'Displacement until 1,399cc', '1400 until 1999cc', '2000 and more cc', 'unknown', 'With open Construction', 'with all wheel drive', 'namely residential mobile', 'in fact Suffer-car, emergency doctor operational vehicles', 'commercial holder', 'female holder', 'Car Density per 1000 resident']

# Assign the new column names to the DataFrame
new_mvr_df.columns = new_column_names

# Display the DataFrame with the updated column names
print(new_mvr_df.columns)
# Out:
# Index(['Year', 'Administrative district',
#        'Statistical code and registration district', 'altogether',
#        'therefrom Two-wheeled Car', 'of that three-wheeled car',
#        'of that light four-wheeled vehicles', 'underneath female Holder',
#        'passenger cars total', 'Displacement until 1,399cc',
#        '1400 until 1999cc', '2000 and more cc', 'unknown',
#        'With open Construction', 'with all wheel drive',
#        'namely residential mobile',
#        'in fact Suffer-car, emergency doctor operational vehicles',
#        'commercial holder', 'female holder', 'Car Density per 1000 resident'],
#       dtype='object')

# %%
# Specify the number of columns to include
num_columns = 7

# Slice the DataFrame to exclude the first row and store up to the specified number of columns
new_bs_df = BS_df.iloc[:, :num_columns]

# Display the new DataFrame with added column names and no first row
print(new_bs_df.columns)
# Out:
# Index(['datum', 'uhrzeit_start', 'uhrzeit_ende', 'zaehlstelle', 'richtung_1',
#        'richtung_2', 'gesamt'],
#       dtype='object')

# %%
#Assigning New Column Names in English to Munich Bike Sharing Data

# Define the new column names
new_column_names = ['Date', 'Time_Start', 'Time_End', 'Counting_Station', 'Direction_1', 'Direction_2', 'In_total', ]

# Assign the new column names to the DataFrame
new_bs_df.columns = new_column_names
# Display the DataFrame with the updated column names
print(new_bs_df.columns)
# Out:
# Index(['Date', 'Time_Start', 'Time_End', 'Counting_Station', 'Direction_1',
#        'Direction_2', 'In_total'],
#       dtype='object')

# %%
#**************Removing Missing Values from Data Frames**************

new_mvr_df.dropna()
new_bs_df.dropna()
# Out:
#              Date Time_Start Time_End Counting_Station  Direction_1  \
# 0      2017.01.01      00:00    23:59           Arnulf          121
# 1      2017.01.01      00:00    23:59          Erhardt          253
# 2      2017.01.01      00:00    23:59           Hirsch           67
# 3      2017.01.01      00:00    23:59         Kreuther           14
# 4      2017.01.01      00:00    23:59       Margareten          197
# ...           ...        ...      ...              ...          ...
# 13141  2022.12.31      00:00    23:59          Erhardt          950
# 13142  2022.12.31      00:00    23:59           Hirsch          240
# 13143  2022.12.31      00:00    23:59         Kreuther          149
# 13144  2022.12.31      00:00    23:59       Margareten          793
# 13145  2022.12.31      00:00    23:59          Olympia          609
#
#        Direction_2  In_total
# 0               14       135
# 1              278       531
# 2               74       141
# 3               16        30
# 4              187       384
# ...            ...       ...
# 13141          918      1868
# 13142          285       525
# 13143          124       273
# 13144          774      1567
# 13145          493      1102
#
# [13146 rows x 7 columns]

# %%
createDb = create_engine("sqlite:///Munich_VR_&_BS.db")

#Creating SQL database for Munich Vehicle Registration data
new_mvr_df.to_sql("MVR_DATA", createDb, if_exists="replace")

#Creating SQL database for Munich Bike Sharing Data 

new_bs_df.to_sql("BS_DATA", createDb, if_exists="replace")
# Out:
# 13146

# %%
# Data Summary
print("Munich Vehicle Registration Data Summary:")
print(new_mvr_df.shape)  # Shape of the data frame
print(new_mvr_df.describe())  # Summary statistics
print(new_mvr_df.dtypes)  # Data types of columns
# Out:
# Munich Vehicle Registration Data Summary:
# (45, 20)
#               Year     altogether  therefrom Two-wheeled Car  \
# count     5.000000      45.000000                  45.000000
# mean   2020.000000   27996.311111               27236.977778
# std       1.581139   35873.759811               34906.755711
# min    2018.000000    6094.000000                5967.000000
# 25%    2019.000000   10498.000000               10268.000000
# 50%    2020.000000   14380.000000               14009.000000
# 75%    2021.000000   23245.000000               22497.000000
# max    2022.000000  131099.000000              127562.000000
#
#        of that three-wheeled car  of that light four-wheeled vehicles  \
# count                  45.000000                            45.000000
# mean                  258.044444                           501.288889
# std                   333.330982                           644.599863
# min                    43.000000                            64.000000
# 25%                   106.000000                           149.000000
# 50%                   136.000000                           286.000000
# 75%                   200.000000                           430.000000
# max                  1368.000000                          2347.000000
#
#        underneath female Holder  passenger cars total  \
# count                 45.000000          4.500000e+01
# mean                3876.622222          3.339699e+05
# std                 4976.888277          4.260166e+05
# min                  806.000000          6.670900e+04
# 25%                 1515.000000          1.379300e+05
# 50%                 1946.000000          1.725800e+05
# 75%                 3115.000000          2.782710e+05
# max                18168.000000          1.539747e+06
#
#        Displacement until 1,399cc  1400 until 1999cc  2000 and more cc  \
# count                   45.000000          45.000000         45.000000
# mean                126633.244444      159420.311111      46276.355556
# std                 161936.201127      203204.009016      58924.628900
# min                  27860.000000       30070.000000       8674.000000
# 25%                  51461.000000       67739.000000      19646.000000
# 50%                  63290.000000       83818.000000      25194.000000
# 75%                 101827.000000      136124.000000      38511.000000
# max                 584333.000000      727387.000000     208931.000000
#
#             unknown  With open Construction  with all wheel drive  \
# count     45.000000               45.000000             45.000000
# mean    1640.000000            15408.844444          29518.088889
# std     3305.532174            19699.834972          37989.738497
# min       49.000000             3603.000000           4545.000000
# 25%      231.000000             6345.000000          12034.000000
# 50%      548.000000             7853.000000          16082.000000
# 75%     1631.000000            11296.000000          24781.000000
# max    20337.000000            70147.000000         153185.000000
#
#        namely residential mobile  \
# count                  45.000000
# mean                 4589.777778
# std                  6013.774907
# min                   459.000000
# 25%                  1945.000000
# 50%                  2877.000000
# 75%                  3789.000000
# max                 26208.000000
#
#        in fact Suffer-car, emergency doctor operational vehicles  \
# count                                          45.000000
# mean                                          134.888889
# std                                           171.355190
# min                                            20.000000
# 25%                                            72.000000
# 50%                                            77.000000
# 75%                                           104.000000
# max                                           643.000000
#
#        commercial holder  female holder  Car Density per 1000 resident
# count          45.000000      45.000000                      45.000000
# mean        28975.822222  116703.955556                     572.133333
# std         36860.422913  149143.695754                      58.819678
# min          4229.000000   24441.000000                     462.000000
# 25%         11023.000000   48849.000000                     559.000000
# 50%         20183.000000   59246.000000                     587.000000
# 75%         23267.000000   95576.000000                     617.000000
# max        137273.000000  541442.000000                     649.000000
# Year                                                         float64
# Administrative district                                       object
# Statistical code and registration district                    object
# altogether                                                     int64
# therefrom Two-wheeled Car                                      int64
# of that three-wheeled car                                      int64
# of that light four-wheeled vehicles                            int64
# underneath female Holder                                       int64
# passenger cars total                                           int64
# Displacement until 1,399cc                                     int64
# 1400 until 1999cc                                              int64
# 2000 and more cc                                               int64
# unknown                                                        int64
# With open Construction                                         int64
# with all wheel drive                                           int64
# namely residential mobile                                      int64
# in fact Suffer-car, emergency doctor operational vehicles      int64
# commercial holder                                              int64
# female holder                                                  int64
# Car Density per 1000 resident                                  int64
# dtype: object

# %%
print("Munich Bike Sharing Data Summary:")
print(new_bs_df.shape)  # Shape of the data frame
print(new_bs_df.describe())  # Summary statistics
print(new_bs_df.dtypes)  # Data types of columns
# Out:
# Munich Bike Sharing Data Summary:
# (13146, 7)
#         Direction_1   Direction_2      In_total
# count  13146.000000  13146.000000  13146.000000
# mean    1063.145291    900.099270   1963.244561
# std      945.422773    930.385164   1828.565104
# min        0.000000      0.000000      0.000000
# 25%      355.000000    144.250000    613.250000
# 50%      823.000000    594.000000   1393.000000
# 75%     1502.000000   1355.750000   2714.500000
# max     6152.000000   6131.000000  12283.000000
# Date                object
# Time_Start          object
# Time_End            object
# Counting_Station    object
# Direction_1          int64
# Direction_2          int64
# In_total             int64
# dtype: object

# %%
# Data Visualization
plt.figure(figsize=(10, 6))
sns.countplot(x='Year', data=new_mvr_df)
plt.title('Vehicle Registrations by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Date', y='In_total', data=new_bs_df)
plt.title('Bike Rentals over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Data Manipulation
total_registrations_year = new_mvr_df.groupby('Year')['altogether'].sum()
avg_bikes_rented_day = new_bs_df.groupby('Date')['In_total'].mean()

# %%
# Data Aggregation and Analysis
registrations_by_district = new_mvr_df.groupby('Administrative district')['altogether'].sum()
rentals_by_station = new_bs_df.groupby('Counting_Station')['In_total'].sum()

# %%
# Correlation Analysis
mvr_bs_merged = pd.merge(new_mvr_df, new_bs_df, on='Date', how='inner')
correlation = mvr_bs_merged[['altogether', 'In_total']].corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18612\1624155426.py in ?()
# ----> 2 # Correlation Analysis
#       3 mvr_bs_merged = pd.merge(new_mvr_df, new_bs_df, on='Date', how='inner')
#       4 correlation = mvr_bs_merged[['altogether', 'In_total']].corr()
#
# C:\anaconda3\envs\FP\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     106     copy: bool = True,
#     107     indicator: bool = False,
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#
# C:\anaconda3\envs\FP\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699         (
#     700             self.left_join_keys,
#     701             self.right_join_keys,
#     702             self.join_names,
# --> 703         ) = self._get_merge_keys()
#     704
#     705         # validate the merge keys dtypes. We may need to coerce
#     706         # to avoid incompatible dtypes
#
# C:\anaconda3\envs\FP\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1175                     if lk is not None:
#    1176                         # Then we're either Hashable or a wrong-length arraylike,
#    1177                         #  the latter of which will raise
#    1178                         lk = cast(Hashable, lk)
# -> 1179                         left_keys.append(left._get_label_or_level_values(lk))
#    1180                         join_names.append(lk)
#    1181                     else:
#    1182                         # work-around for merge_asof(left_index=True)
#
# C:\anaconda3\envs\FP\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1846                 .get_level_values(key)  # type: ignore[assignment]
#    1847                 ._values
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#    1853         if values.ndim > 1:
#
# KeyError: 'Date'

# %%
# Print the results
print("Total Registrations per Year:")
print(total_registrations_year)
# Out:
# Total Registrations per Year:
# Year
# 2018.0    6094
# 2019.0    6145
# 2020.0    6167
# 2021.0    6385
# 2022.0    6540
# Name: altogether, dtype: int64

# %%
print("Average Bikes Rented per Day:")
print(avg_bikes_rented_day)
# Out:
# Average Bikes Rented per Day:
# Date
# 2017.01.01     261.833333
# 2017.01.02     492.333333
# 2017.01.03     339.333333
# 2017.01.04     274.500000
# 2017.01.05     220.666667
#                  ...
# 2022.12.27     854.333333
# 2022.12.28     958.500000
# 2022.12.29    1082.166667
# 2022.12.30    1044.666667
# 2022.12.31     964.333333
# Name: In_total, Length: 2191, dtype: float64

# %%
print("Registrations by Administrative District:")
print(registrations_by_district)
# Out:
# Registrations by Administrative District:
# Administrative district
# RB MUENSTER                           6094
# RB MUENSTER                          25237
# Name: altogether, dtype: int64

# %%
print("Rentals by Counting Station:")
print(rentals_by_station)
# Out:
# Rentals by Counting Station:
# Counting_Station
# Arnulf        2125258
# Erhardt       9372539
# Hirsch        2912235
# Kreuther      1017438
# Margareten    6453951
# Olympia       3927392
# Name: In_total, dtype: int64

# %%
# Convert the "Date" column in new_bs_df to datetime if it's not already in datetime format
new_bs_df['Date'] = pd.to_datetime(new_bs_df['Date'])

# Extract the year from the "Date" column
new_bs_df['Year'] = new_bs_df['Date'].dt.year

# Group the data by year and calculate the average of "In_total" for each year
average_bikes_rented_by_year = new_bs_df.groupby('Year')['In_total'].mean()

# Group the data in new_mvr_df by year and calculate the sum of "altogether" for each year
total_registrations_by_year = new_mvr_df.groupby('Year')['altogether'].sum()

# Calculate the correlation between the average number of bikes rented and the total number of registrations
correlation = average_bikes_rented_by_year.corr(total_registrations_by_year)

# Print the correlation
print(correlation)
# Out:
# 0.6416331906441989

# %%
# Convert the "Date" column in new_bs_df to datetime if it's not already in datetime format
new_bs_df['Date'] = pd.to_datetime(new_bs_df['Date'])

# Extract the year from the "Date" column
new_bs_df['Year'] = new_bs_df['Date'].dt.year

# Group the data by year and calculate the average of "In_total" for each year
average_bikes_rented = new_bs_df.groupby('Year')['In_total'].mean()

# Print the average number of bikes rented per year for all the years
print(average_bikes_rented)
# Out:
# Year
# 2017    1691.901370
# 2018    1874.215982
# 2019    1850.026941
# 2020    2163.688525
# 2021    2008.289498
# 2022    2190.795890
# Name: In_total, dtype: float64

# %%
print("Column names in new_mvr_df:", new_mvr_df.columns)
print("Column names in new_bs_df:", new_bs_df.columns)
# Out:
# Column names in new_mvr_df: Index(['Year', 'Administrative district',
#        'Statistical code and registration district', 'altogether',
#        'therefrom Two-wheeled Car', 'of that three-wheeled car',
#        'of that light four-wheeled vehicles', 'underneath female Holder',
#        'passenger cars total', 'Displacement until 1,399cc',
#        '1400 until 1999cc', '2000 and more cc', 'unknown',
#        'With open Construction', 'with all wheel drive',
#        'namely residential mobile',
#        'in fact Suffer-car, emergency doctor operational vehicles',
#        'commercial holder', 'female holder', 'Car Density per 1000 resident'],
#       dtype='object')
# Column names in new_bs_df: Index(['Date', 'Time_Start', 'Time_End', 'Counting_Station', 'Direction_1',
#        'Direction_2', 'In_total'],
#       dtype='object')

# %%
# Drop the additional column from the new_bs_df DataFrame
new_bs_df = new_bs_df[new_bs_df['Year'] != 2017]
# Calculate the correlation between the average number of bikes rented and the total number of registrations
correlation = average_bikes_rented_by_year.corr(total_registrations_by_year)

# %%
print(average_bikes_rented_by_year)
# Out:
# Year
# 2017    1691.901370
# 2018    1874.215982
# 2019    1850.026941
# 2020    2163.688525
# 2021    2008.289498
# 2022    2190.795890
# Name: In_total, dtype: float64

# %%
print(total_registrations_by_year)
# Out:
# Year
# 2018.0    6094
# 2019.0    6145
# 2020.0    6167
# 2021.0    6385
# 2022.0    6540
# Name: altogether, dtype: int64
